# %%
import os

# %pwd
# Out:
# 'c:\\Users\\manju\\Documents\\ws\\Reimbursement\\ChickenDiseaseClassification-MLOPS-e2e\\research'

# %%
# Change working directory to parent directory
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\manju\\Documents\\ws\\Reimbursement\\ChickenDiseaseClassification-MLOPS-e2e'
